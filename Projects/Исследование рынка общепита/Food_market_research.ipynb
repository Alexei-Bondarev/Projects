# %% [markdown]
# <div class = "alert alert-info" >
# <h2>Комментарий студента 2:</h2>
#
# Вроде поправил проект: да про id в дубликатах забыл совсем или недосмотрел, без этого столбца нашлось 82 дублирующихся строки, если включать все столбцы (кроме id). После приведения к нижнему регистру так же 3 дублирующихся строки нашлось. Выводы по графикам с замечаниями  переделал. По split в адресах, да увидел что не все соединилось уже в конце проекта, в основном это адреса где в строке адреса есть условно говоря элемент типа (3-й, 1-я и т.д) и стоят они на тех же местах что и элементы (улица, проезд и т.д), т.е их можно добавить в мой список mask и тогда по идее они попадут в сравнении и по ним так же произойдет соединени. Вообще если честно то на парсинг данных и соединение таблиц ушло процентов 85 времени от всего проекта если не больше, хотя он вроде как про графики и презентацию((( По плотности улицы - попробовал подправить расчеты, и найти эту метрику, а так же вывел новые данные на график. Так же добавил боксплоты для топ 10 улиц по посадочным местам. И сделал итоговую рекомендацию по поводу типа, места, количества посадочных мест и перспективы развития в сеть открывающегося объекта. Но надо заметить что данных все же недостаточно я думаю, что бы опираться на них на 100% для подобных рекомендаций. Все доработки помечены как - Комментарий студента 2. Спасибо за рекомендации.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера V.2</h2>
#
# Спасибо, что прокомментировал, удачи в следующих спринтах 💪
#
# > Но надо заметить что данных все же недостаточно я думаю, что бы опираться на них на 100% для подобных рекомендаций
#
# Да, это всё таки домашнее задание, а не полноценное исследование :)
#
# > т.е их можно добавить в мой список mask и тогда по идее они попадут в сравнении и по ним так же произойдет соединени.
#
# Ну с Крутицким переулком это не сработает, т.к. твоя трансформация превратит `"3-й Крутицкий переулок"` в `"Крутицкий переулок 3-й"`, а в таблице с улицами у нас `"Крутицкий 3-й, переулок"`
#
# >  хотя он вроде как про графики и презентацию(((
#
# Ну мне кажется графиков и до этого было достаточно, а повытаскивать руками данные откуда-нибудь достаточно интересно, чувствуешь себя дата-инженером :)
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> Комментарий студента: Здравствуйте! Очень сильно задержало выполнение проекта, то что часть информации нужно было искать во внешних источниках. Данные улиц по районам скопированны с сайта - http://mosopen.ru/streets, процесс выполнялся в два этапа - формирование списка районов и формирование списка улиц с районами. Данные для проекта беруться непосредственно ссайта, что может занять длительное время (но не более 30-60 сек). Так же на всякий случай записал данные в отдельный файл. Надеюсь все верно. Ссылка на презентацию - https://drive.google.com/file/d/1DiPpp_-SAH0YCI2rVl0s7KOBoGdQAjMC/view?usp=sharing с правами редактор. И вопрос можно что-то посоветовать в плане изучения написания кода (алгоритма). Проблема в том, что у меня это занимает очень много времени, проекты по времени практически не успеваю здавать во время.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Привет! Меня зовут Алексей Тюрин, я буду делать ревью этой работы. Давай будем общаться на «ты».
#
# У тебя хорошая, внимательная работа 👍. Есть пара неточностей, которые быстро исправляются. Как со всем разберешься --- буду рад принять работу, удачи :)
#
# > Надеюсь все верно.
#
# Да, всё здорово :)
#
# > И вопрос можно что-то посоветовать в плане изучения написания кода (алгоритма). Проблема в том, что у меня это занимает очень много времени, проекты по времени практически не успеваю здавать во время.
#
# Не очень понял про что вопрос, в смысле как быстрее код писать? Ну только с практикой, нужно либо задачки на код нарешивать, либо делать какие-то проекты на программирование, например какой-нибудь игрушечный веб-сервис можешь сделать, это не так трудно на самом деле или какой-нибудь автоматизатор рутинных задач, которые у тебя может быть возникают. Задачи на код тут например есть: https://leetcode.com/ на `kaggle` тоже можно что-то найти
#
#
# > По презе
#
# Хорошая преза, круто что есть выводы к графикам. Текста на слайдах лучше поменьше, можно было сделать слайд с постановкой задач и пронумеровать слайды. Для през могу порекомендовать сервис: https://readymag.com/
#
# Зелёным цветом отмечены комментарии, формально не требующие правки, но правки приветствуются. Жёлтым цветом выделено то, что в следующий раз можно сделать по-другому или можно поправить прямо сейчас.
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее». Если оставляешь комментарии на какой-то итерации ревью, пиши что-то вроде `комментарий студента V.номер итерации`
# </div>
#
# Цвет можно сделать, например, так
#
# <div class = "alert alert-info" >
# <h2>Комментарий студента</h2>
# Ревьюер душнила :)
# </div>
#
# Или так:
#
# <div class="alert alert-info" style="background:pink;color:#A91E69">
# <h2>Комментарий студента </h2>
#     ...
# </div>

# %% [markdown]
# # Исследование рынка общественного питания в Москве.
#
# Цель: Исследовать рынок общественного питания г.Москва.

# %% [markdown]
# Описание данных:
# - id — идентификатор объекта;
# - object_name — название объекта общественного питания;
# - chain — сетевой ресторан;
# - object_type — тип объекта общественного питания;
# - address — адрес;
# - number — количество посадочных мест.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import numpy as np
from numpy import median

import requests
import re
from bs4 import BeautifulSoup

pd.set_option('display.max_colwidth',500)
#pd.set_option('display.max_rows', 4300)

import warnings
warnings.filterwarnings('ignore')

try:
    data = pd.read_csv('/datasets/rest_data.csv')
except:
    data = pd.read_csv('C:/Users/K/Desktop/datasets/rest_data.csv')

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# > `warnings.filterwarnings('ignore')`
#
# Все предупреждения не стоит выключать, тут можно посмотреть способы https://stackoverflow.com/questions/14463277/how-to-disable-python-warnings Если коротко, то лучше выключать те, которые надо, каждый модуль может свои предупреждения определять, как например `SetCopyOnWarning`, это который про присваивания. Его можно убрать вообще без фильров:
#     `pd.set_option('chained_assignment', None)`
#
# > `except`
#
# Пустой `except` лучше не писать, так как он ловит все исключения вообще, даже те, которые бросил не твой код. Например, если захочется прибить клетку с кодом, который содержит такой `except`, с помощью кнопки стоп с панели выше, то поведение такого действия будет зависеть от того, что написано в `except`, а должно бы просто останавливать код сразу. Лучше либо писать конкретные типы исключений, либо здесь можно обойтись вообще без них, используя модуль `os`: `import os; if os.path.exists(путь1) .. else:..`
# </div>

# %%
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 6 columns):
# id             15366 non-null int64
# object_name    15366 non-null object
# chain          15366 non-null object
# object_type    15366 non-null object
# address        15366 non-null object
# number         15366 non-null int64
# dtypes: int64(2), object(4)
# memory usage: 720.4+ KB
# None

# %%
# Проверим наличие дубликатов, значения категориальных столбцов.
display(data.head(3))
display("Количество дубликатов: " + str(data.duplicated().sum()))
display("Количество - сетевые/несетевые рестораны: ", data.groupby('chain')['id'].count())
display("Количество заведений по типу объекта: ", data.groupby('object_type')['id'].count())
display("Количество пропущенных значений в столбцах: ", data.isnull().sum())
# Out:
#        id      object_name chain object_type  \
# 0  151635          СМЕТАНА   нет        кафе
# 1   77874           Родник   нет        кафе
# 2   24309  Кафе «Академия»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 'Количество дубликатов: 0'
# 'Количество - сетевые/несетевые рестораны: '
# chain
# да      2968
# нет    12398
# Name: id, dtype: int64
# 'Количество заведений по типу объекта: '
# object_type
# бар                                   856
# буфет                                 585
# закусочная                            360
# кафе                                 6099
# кафетерий                             398
# магазин (отдел кулинарии)             273
# предприятие быстрого обслуживания    1923
# ресторан                             2285
# ...

# %% [markdown]
# <div class="alert alert-info">Вывод: Имена столбцов в нижнем регистре, без пробелов. Типы данных соответствуют содержимому столбцов. Дублирующихся строк, аномальных наименований в категориях и ошибок нет. Пропуски отсутствуют.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Перед тем как смотреть на дубликаты, можно заметить, что как минимум названия написаны разным регистром, т.е. лучше привести к одному, а как максимум написаны в разнобой, тут уже необязательно, но можно попробовать привести всё к одному виду, типа макдональс, макдоналдс, mcdonalds $\to$ макдоналдс . Тут можно либо руками, либо поиграться с метриками похожести слов https://ru.wikipedia.org/wiki/%D0%A0%D0%B0%D1%81%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D0%B5_%D0%9B%D0%B5%D0%B2%D0%B5%D0%BD%D1%88%D1%82%D0%B5%D0%B9%D0%BD%D0%B0 или чем-то таким https://rusvectores.org/ru/associates/
#
# Ещё тут есть уникальный столбец `id`, поэтому с ним бессмысленно искать дубликаты, зато можно поискать без него. Тако йстолбец часто автоинкрементируется в реляционных базах данных, даже если вставляется уже формально существующая запись
# </div>

# %% [markdown]
# <div class="alert alert-info"><h2> Комментарий студента 2:</h2> Привел к нижнему регистру названия заведений. Проверил дубликаты по все столбцам без id, 85 строк дубликатов удалены.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера V.2</h2>
#
# 👍
# </div>

# %%
# Приведем значения столбца - 'object_name' к нижнему регистру:
data['object_name'] = data['object_name'].str.lower()

# Посчитаем дубликаты:
display("Всего строк в данных: ", len(data))
duplicate_row = data[data[['object_name', 'chain','object_type','address','number']].duplicated()].sort_values(by='address')
display("Всего дубликатов: ", len(duplicate_row))

# Удалим дубликаты:
data = data.drop_duplicates(subset=['object_name', 'chain','object_type','address','number'], keep='first')
display("Строк осталось: ", len(data))
# Out:
# 'Всего строк в данных: '
# 15366
# 'Всего дубликатов: '
# 85
# 'Строк осталось: '
# 15281

# %%
# Заменим обозначение сетевых и несетевых объектов:
display(data.head(10))
data['chain'] = data['chain'].replace('нет', 'несетевые')
data['chain'] = data['chain'].replace('да', 'сетевые')
display(data.head(10))
# Out:
#        id               object_name chain object_type  \
# 0  151635                   сметана   нет        кафе
# 1   77874                    родник   нет        кафе
# 2   24309           кафе «академия»   нет        кафе
# 3   21894                пиццетория    да        кафе
# 4  119365    кафе «вишневая метель»   нет        кафе
# 5   27429  стол. при гоу сош № 1051   нет    столовая
# 6  148815                  брусника    да        кафе
# 7   20957               буфет мтуси   нет    столовая
# 8   20958               кпф семья-1   нет    столовая
# 9   28858            столовая мтуси   нет    столовая
#
#                                                address  number
# 0           город Москва, улица Егора Абакумова, дом 9      48
# 1    город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2            город Москва, Абельмановская улица, дом 6      95
# 3              город Москва, Абрамцевская улица, дом 1      40
# ...

# %% [markdown]
# ## Анализ данных:

# %% [markdown]
# ### Исследуйте соотношение видов объектов общественного питания по количеству. Постройте график.

# %%
type_object = data.groupby('object_type')['id'].count().sort_values(ascending=True).reset_index()
display(type_object)

with plt.style.context('seaborn-white'):
    sns.set_style('whitegrid')
    plt.figure(figsize=(14, 5))
    sns.set_palette('pastel') 
    ax = sns.barplot(x='id', y='object_type', data=type_object, )
    plt.title('Количество объектов по типу', fontdict=({'fontsize':25}))
    plt.xlabel("", fontdict=({'fontsize':20}))
    plt.xlabel("Количество", fontdict=({'fontsize':20}))
    plt.ylabel("")

# 2-й способ через plt:
#display(plt.style.available)
#with plt.style.context('seaborn-paper'):
#    plt.figure(figsize=(14,4))
#    plt.barh(type_object['object_type'], type_object['id'], linewidth=10) #2F5D62
#    plt.title('Количество объектов по типу')
#    plt.xlabel('Количество')
# Out:
#                          object_type    id
# 0          магазин (отдел кулинарии)   273
# 1                         закусочная   348
# 2                          кафетерий   395
# 3                              буфет   576
# 4                                бар   855
# 5  предприятие быстрого обслуживания  1897
# 6                           ресторан  2282
# 7                           столовая  2584
# 8                               кафе  6071

# %% [markdown]
# <div class="alert alert-info"> Вывод: Большее число объектов принадлежит к типу кафе и составляет почти половину от общего числа объектов. Далее следуют столовые, рестораны и предприятия быстрого обслуживания.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Круто, что умеешь и так и так :)
# </div>

# %% [markdown]
# ### Исследуйте соотношение сетевых и несетевых заведений по количеству. Постройте график.

# %%
chain = data.groupby('chain')['id'].count().reset_index()
display(chain)

plt.figure(figsize=(10,7))
sns.set_style('whitegrid')
plt.bar(chain['chain'], chain['id'], linewidth=0, color='#5E8B7E', width=0.5)
plt.title('Количество сетевых/несетевых объектов', fontdict=({'fontsize':25}))
# Out:
#        chain     id
# 0  несетевые  12317
# 1    сетевые   2964
# Text(0.5, 1.0, 'Количество сетевых/несетевых объектов')

# %% [markdown]
# <div class="alert alert-info"> Вывод: Количество сетевых объектов в 4 раза меньше количества несетевых: 2968 против 12398.

# %% [markdown]
# ### Для какого вида объекта общественного питания характерно сетевое распространение?

# %%
# Посмотрим доли сетевых и не сетвых объектов по каждуму виду объекта:
display(data.head(2))

#Построим сводную таблицу:
chain_pivot = data.pivot_table(index='chain', columns='object_type', values='id', aggfunc='count')
display(chain_pivot.head(2))
chain_pivot = data.groupby(['chain', 'object_type'])['id'].count().reset_index()
display(chain_pivot.head(2))


fig = px.bar(chain_pivot, x='object_type', y='id', color='chain', color_discrete_map={"да": "red", "нет": "green"}, title="Доля сетевых/несетевых объектов общественного питания")
fig.update_xaxes(title_text="Объект общественного питания",)
fig.update_yaxes(title_text="Количество")
fig.update_xaxes(title_text="",)
fig.update_yaxes(title_text="")
fig.show()
# Out:
#        id object_name      chain object_type  \
# 0  151635     сметана  несетевые        кафе
# 1   77874      родник  несетевые        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# object_type  бар  буфет  закусочная  кафе  кафетерий  \
# chain
# несетевые    818    565         292  4675        343
# сетевые       37     11          56  1396         52
#
# object_type  магазин (отдел кулинарии)  предприятие быстрого обслуживания  \
# chain
# несетевые                          195                               1109
# сетевые                             78                                788
#
# object_type  ресторан  столовая
# chain
# несетевые        1739      2581
# сетевые           543         3
#        chain object_type   id
# 0  несетевые         бар  818
# 1  несетевые       буфет  565
# <div>
#
#
# ...

# %% [markdown]
# <div class="alert alert-info"> Вывод: Всего 3 типа объектов общественного питания имеют относительно значимую долю сетевых объектов. Это кафе, рестораны и предприятия быстрого обслуживания.

# %% [markdown]
# <div class="alert alert-warning">
# <h2>Комментарий ревьюера</h2>
#
# График верный, а вот вывод не совсем. Нас интересовала характерность быть сетевым заведением: пусть в городе 15 баров, 14 из которых сетевые, и 200 кафе, 50 из которых - сетевые. Тогда именно для баров будет характерно сетевое распределение, а не для кафе. Хотя формально сетевых кафе у нас больше, чем сетевых баров.
# </div>

# %% [markdown]
# <div class="alert alert-info"><h2> Комментарий студента 2:</h2> Если правильно понял замечание, то по графику видно, что для всех типов объектов не характерно быть сетевыми заведениями. Так как ни в одном типе объектов доля сетевых не превышает и половины.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера V.2</h2>
#
# Ну в этом смысле ты прав :) Но если это отбросить, то в каких-то типах вероятнее наткнуться на сетевое заведение, чем в других:
# </div>

# %%
# Код ревьюера
chain_by_rest_type = data.groupby('object_type').apply(lambda x: pd.Series(dict(
    chained=(x.chain == 'сетевые').sum(),
    not_chained=(x.chain == 'несетевые').sum(),
    total =x.id.count()
)))


chain_by_rest_type = chain_by_rest_type.reset_index()
chain_by_rest_type['chained_share'] = chain_by_rest_type['chained']/chain_by_rest_type['total']*100
chain_by_rest_type['not_chained_share'] = chain_by_rest_type['not_chained']/chain_by_rest_type['total']*100

chain_by_rest_type.sort_values(by='chained_share', ascending=False)
# Out:
#                          object_type  chained  not_chained  total  \
# 6  предприятие быстрого обслуживания      787         1108   1895
# 5          магазин (отдел кулинарии)       78          195    273
# 7                           ресторан      542         1737   2279
# 3                               кафе     1395         4662   6057
# 2                         закусочная       56          289    345
# 4                          кафетерий       52          343    395
# 0                                бар       37          818    855
# 1                              буфет       11          564    575
# 8                           столовая        3         2581   2584
#
#    chained_share  not_chained_share
# 6      41.530343          58.469657
# 5      28.571429          71.428571
# 7      23.782361          76.217639
# 3      23.031204          76.968796
# 2      16.231884          83.768116
# 4      13.164557          86.835443
# 0       4.327485          95.672515
# ...

# %% [markdown]
# ### Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?

# %%
display(data)
# Out:
#            id             object_name      chain object_type  \
# 0      151635                 сметана  несетевые        кафе
# 1       77874                  родник  несетевые        кафе
# 2       24309         кафе «академия»  несетевые        кафе
# 3       21894              пиццетория    сетевые        кафе
# 4      119365  кафе «вишневая метель»  несетевые        кафе
# ...       ...                     ...        ...         ...
# 15361  208537             шоколадница    сетевые        кафе
# 15362  209264             шоколадница    сетевые        кафе
# 15363  209186             шоколадница    сетевые        кафе
# 15364  221900             шоколадница    сетевые        кафе
# 15365  222535             шоколадница    сетевые        кафе
#
#                                                                                              address  \
# 0                                                         город Москва, улица Егора Абакумова, дом 9
# ...

# %%
chain = data[data['chain'] == 'сетевые']

# Построим сводную таблицу для сетевых заведений:
pivot_chain = chain.pivot_table(index='object_name', aggfunc={'id':'count', 'number':'sum'}).sort_values(by='id', ascending=False).reset_index()
pivot_chain.columns = ['object_name', 'total_objects', 'total_seats']

# Посчитаем среднее количество количество посадочных мест на одно заведение: 
pivot_chain['seats_per_cafe'] = pivot_chain['total_seats']/pivot_chain['total_objects']

#Посмотрим график распределения - количество заведений в сети/среднее количество посадочных мест на заведение:
g=sns.jointplot(x='total_objects', y='seats_per_cafe', data=pivot_chain, color='green',  height=10, kind='reg')
plt.title('Распределение среднего числа посадочных мест объекта по сетям', fontdict=({'fontsize':18}), loc='left')
g.set_axis_labels("Количество объектов в сети", "Среднее количество посадочных мест")

# %% [markdown]
# <div class="alert alert-info"> Вывод: Для сетевых заведений характерно - не большое количество заведений - до 10, среднее значение количества посадочных мест до 100.

# %% [markdown]
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера</h2>
#
# Верный график и опять же не совсем тот вывод :) Как ты определял где параметр большой, а где нет? `reg` тут не особо нужен, т.к. видно что не особо корреляируют величины. Вопрос был про: "Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?". Чтобы было понятнее можно перефразировать:
#
# Если взять случайное сетевое заведение, то вероятность какого события выше?
# <li>Наткнуться на сеть с <b>большим</b> числом посадочных мест и <b>небольшим</b> числом заведений в сети</li>
# <li>Наткнуться на сеть с <b>небольшим</b> числом посадочных мест и <b>большим</b> числом заведений в сети</li>
# <li>Наткнуться на сеть с <b>небольшим</b> числом посадочных мест и <b>небольшим</b> числом заведений в сети</li>
# <li>Наткнуться на сеть с <b>большим</b> числом посадочных мест и <b>большим</b> числом заведений в сети</li>
# </div>

# %% [markdown]
# <div class="alert alert-info"><h2> Комментарий студента 2:</h2> Потому что большинство заведений принадлежит к сети с количеством до 10, а то и до 5 объектов, тогда как максимальное число объектов в сети может быть до 160. Тогда получается, что если взять случайное сетевое заведение, то вероятнее всего это будет - сеть с небольшим числом заведений и большим числом посадочных мест.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера V.2</h2>
#
# Ну, логично наверное было определять большой параметр или нет, основываясь не на максимуме, а на каких-то других перцентилях, например сравнивая с медианой
# </div>

# %% [markdown]
# ### Для каждого вида объекта общественного питания опишите среднее количество посадочных мест. Какой вид предоставляет в среднем самое большое количество посадочных мест? Постройте графики.

# %%
pivot_object = data.pivot_table(index='object_type', aggfunc={'number':'mean'}).sort_values(by='number', ascending=False).reset_index()

display(pivot_object)

plt.figure(figsize=(15,16))
g=sns.catplot(x='object_type', y='number', data=data, kind="box", height=6, aspect=2.5)
g.set(ylim=(0, 410))
g.set_axis_labels("", "Среднее количество посадочных мест")
plt.title('Количество посадочных мест по типу объекта', fontdict=({'fontsize':25}))

g.set_xticklabels(rotation=-45)
# Out:
#                          object_type      number
# 0                           столовая  130.337848
# 1                           ресторан   96.884750
# 2                              буфет   51.425347
# 3                                бар   43.533333
# 4                               кафе   39.785703
# 5  предприятие быстрого обслуживания   20.808645
# 6                          кафетерий    9.184810
# 7                         закусочная    7.847701
# 8          магазин (отдел кулинарии)    5.589744

# %% [markdown]
# <div class="alert alert-info"> Вывод: Самое высокое среднее значение посадочных мест в столовых, достигает 100. Далее следуют рестораны - около 80, кафе, бары и буфеты со значением - около 30. Закусочные, предприятия быстрого обслуживания, кафетерии, отделы кулинарии в магазинах имеют единицы посадочных мест или 0.

# %% [markdown]
# ### Выделите в отдельный столбец информацию об улице из столбца address.

# %%
# С помощью функции разделим значения адреса в столбце - address, на элементы, разделенные запятой:
data['split_street'] = None
def split_street(string):
    street = string.split(',')
    return street

data['split_street'] = data['address'].apply(split_street)

# Список наименований типов улиц:
mask = ['улица', 'бульвар', 'шоссе','переулок','переулок', 'проезд', 'проспект', 'набережная', 'площадь', 'аллея', 'квартал', 'Проезд'
       , 'микрорайон', 'город Зеленоград', 'деревня', 'посёлок', 'село', 'линия', 'тупик', '87-й километр', '80-й километр'
        , '82-й километр', '33-й километр', '38-й километр', '104-й километр', '19-й километр', '73-й километр'
        ,'территория Ленинские Горы', 'территория СНТ "Гавриково-1"']

# С помощью функции выделим из списка элементов(столбец split street) название улицы:
def find_street(i):
    for k in range(len(i)):
        for m in mask:
            if m in i[k]:
                return i[k]
            
data['street'] = data['split_street'].apply(find_street)
display(data)
# Out:
#            id             object_name      chain object_type  \
# 0      151635                 сметана  несетевые        кафе
# 1       77874                  родник  несетевые        кафе
# 2       24309         кафе «академия»  несетевые        кафе
# 3       21894              пиццетория    сетевые        кафе
# 4      119365  кафе «вишневая метель»  несетевые        кафе
# ...       ...                     ...        ...         ...
# 15361  208537             шоколадница    сетевые        кафе
# 15362  209264             шоколадница    сетевые        кафе
# 15363  209186             шоколадница    сетевые        кафе
# 15364  221900             шоколадница    сетевые        кафе
# 15365  222535             шоколадница    сетевые        кафе
#
#                                                                                              address  \
# 0                                                         город Москва, улица Егора Абакумова, дом 9
# ...

# %% [markdown]
# <div class="alert alert-info"> Комментарий студента: Так как для выполнения заданий проекта необходимы районы, в которых расположены улицы, воспользуемся сайтом - http://mosopen.ru/streets, на котором есть информация об улицах г. Москвы с разбивкой по районам. Сформируем новый DataFrame, который будет содержать пары значений - улица - районы в два этапа.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Хороша идея и реализовано аккуратно 👍 Можно было наверное обойтись одним датафреймом и руками не дропать неудобные районы, а в какой-то момент ловить исклбчение, если что-то не нашлось, но это мелочи
# </div>

# %%
# Этап 1:

# Получим таблицу содержащую - наименование района и ссылку ведущую на страницу со списком улиц района:
URL = 'http://mosopen.ru/streets'
req = requests.get(URL)
soup = BeautifulSoup(req.text, 'lxml')

# Создаем пустые списки:
district_ref_list = []
district_name_list = []

# Заполняем таблицу записями(ссылка - район), которые находятся в теге <a> с параметром 'href', содержащим ссылку вида - "^http://mosopen.ru/region/"
for row in soup.find_all('a', attrs={'href': re.compile("^http://mosopen.ru/region/")}):
    dist_ref = row.get('href')
    dist_name = row.text   
    district_ref_list.append(dist_ref)
    district_name_list.append(dist_name)

district_data = {'district_ref' : district_ref_list, 'district_name' : district_name_list}
d_data = pd.DataFrame(district_data)

# Удалим дубликаты из таблицы:
d_data.drop_duplicates(inplace=True)

# Удалим строки с нестандартными страницами:
d_data = d_data.drop(d_data.index[20]).reset_index(drop=True)
d_data = d_data.drop(d_data.index[69]).reset_index(drop=True)
d_data = d_data.drop(d_data.index[72])
display(d_data.head(3))
# Out:
#                                       district_ref  district_name
# 0  http://mosopen.ru/region/akademicheskij/streets  Академический
# 1    http://mosopen.ru/region/alekseevskij/streets   Алексеевский
# 2     http://mosopen.ru/region/altufevskij/streets   Алтуфьевский

# %%
# Этап 2:

pd.set_option('display.max_rows', 4180)

# Создаем пустой DataFrame:
all_street_list = pd.DataFrame()


for path, name in zip(d_data['district_ref'], d_data['district_name']):    
    URL = path
    req = requests.get(URL)
    soup = BeautifulSoup(req.text, 'lxml')
    street_list = []
    for row in soup.find_all('div', attrs={'class': 'double_block clearfix'}):
        street_list.append(row.text)

# Разделим полученный список по значению - '\n':
    st = street_list[0].split('\n')

# Удалим пустые значения - ''
    s_list = [st for st in st if st]

# Поместим значения списка в DataFrame:
    s_data = pd.DataFrame(s_list)

#Создадим столбец для наименования районов:
    s_data['dist_name'] =  name
    
#Собираем улицы каждого района в один DataFrame:    
    all_street_list = pd.concat([all_street_list, s_data])           

# Переименуем столбцы:
all_street_list.columns = ['street_name', 'dist_name']
display(all_street_list.head(2))
# Out:
#                     street_name      dist_name
# 0    60-летия Октября, проспект  Академический
# 1  Большая Черёмушкинская улица  Академический

# %%
# Добавим районы которые проходит улица в запись улицы:
group_street = all_street_list.copy()
group_street = group_street.groupby('street_name')['dist_name'].apply(lambda x: x.unique()).reset_index()

display(group_street.head(2))
# Out:
#                street_name    dist_name
# 0             1 Мая, улица    [Крюково]
# 1  10-летия Октября, улица  [Хамовники]

# %%
#Запишем полученные данные в файл:
#group_street.to_csv (r'C:\Users\K\Desktop\datasets\group_street.csv', index = True, header=True)

# %%
#Удалим строки с нулевыми значениями:
display(len(data))
display(data[data['street'].isnull()].head(2))

data.dropna(subset=['street'], inplace=True)
display(len(data))
# Out:
# 15281
#          id            object_name      chain object_type  \
# 6119  25516  ресторан «бони мария»  несетевые    ресторан
# 6606  19912                 сахара  несетевые        кафе
#
#                                                                                   address  \
# 6119  город Москва, 42-й километр Московской Кольцевой Автодороги, владение 4, строение 1
# 6606                  город Москва, 56-й километр Московской Кольцевой Автодороги, дом 10
#
#       number  \
# 6119     170
# 6606       1
#
#                                                                                   split_street  \
# 6119  [город Москва,  42-й километр Московской Кольцевой Автодороги,  владение 4,  строение 1]
# 6606                   [город Москва,  56-й километр Московской Кольцевой Автодороги,  дом 10]
#
#      street
# 6119   None
# 6606   None
# 15258

# %%
#Удалим символы пробела в адресах по краям строки в двух таблицах:
data['street'] = data['street'].str.strip()
group_street['street_name'] = group_street['street_name'].str.strip()

# Удалим запятые из адресов:
data['street'] = data['street'].str.replace(',','')
group_street['street_name'] = group_street['street_name'].str.replace(',','')

# Проверка улиц, содержащих запятые:
display(data[data['street'].str.contains(',')])
display(group_street[group_street['street_name'].str.contains(',')])
# Out:
# Empty DataFrame
# Columns: [id, object_name, chain, object_type, address, number, split_street, street]
# Index: []
# Empty DataFrame
# Columns: [street_name, dist_name]
# Index: []

# %%
# Так как полученный список районов содержит наименование улиц в формате: "название улица", а в исходной таблице встречаются разные варианты:
# и "название улица" и "улица название" то в исходной таблице перенесем слово улица в конец строки наименования улицы:

def format_line(i):
    for m in mask:
        if i.startswith(m):            
            i=i.replace(m,'')
            i = i + ' ' + m            
            return i
    return i

# Проверим полученный реультат в столбце - format_street:
data['format_street'] = data['street'].apply(format_line)
display(data)
# Out:
#            id             object_name      chain object_type  \
# 0      151635                 сметана  несетевые        кафе
# 1       77874                  родник  несетевые        кафе
# 2       24309         кафе «академия»  несетевые        кафе
# 3       21894              пиццетория    сетевые        кафе
# 4      119365  кафе «вишневая метель»  несетевые        кафе
# ...       ...                     ...        ...         ...
# 15361  208537             шоколадница    сетевые        кафе
# 15362  209264             шоколадница    сетевые        кафе
# 15363  209186             шоколадница    сетевые        кафе
# 15364  221900             шоколадница    сетевые        кафе
# 15365  222535             шоколадница    сетевые        кафе
#
#                                                                                              address  \
# 0                                                         город Москва, улица Егора Абакумова, дом 9
# ...

# %%
# Выведем таблицы которые соединим:
display(data.head(2))
display(group_street.head(2))
# Out:
#        id object_name      chain object_type  \
# 0  151635     сметана  несетевые        кафе
# 1   77874      родник  несетевые        кафе
#
#                                              address  number  \
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
#
#                                              split_street  \
# 0          [город Москва,  улица Егора Абакумова,  дом 9]
# 1  [город Москва,  улица Талалихина,  дом 2/1,  корпус 1]
#
#                   street           format_street
# 0  улица Егора Абакумова   Егора Абакумова улица
# 1       улица Талалихина        Талалихина улица
#               street_name    dist_name
# 0             1 Мая улица    [Крюково]
# 1  10-летия Октября улица  [Хамовники]

# %%
#Соединим полученные таблицы, проверим присоединение районов:
data['format_street'] = data['format_street'].str.strip()
all_data = pd.merge(data, group_street, left_on='format_street', right_on='street_name', how='left').reset_index()
display(all_data)
# Out:
#        index      id             object_name      chain object_type  \
# 0          0  151635                 сметана  несетевые        кафе
# 1          1   77874                  родник  несетевые        кафе
# 2          2   24309         кафе «академия»  несетевые        кафе
# 3          3   21894              пиццетория    сетевые        кафе
# 4          4  119365  кафе «вишневая метель»  несетевые        кафе
# ...      ...     ...                     ...        ...         ...
# 15253  15253  208537             шоколадница    сетевые        кафе
# 15254  15254  209264             шоколадница    сетевые        кафе
# 15255  15255  209186             шоколадница    сетевые        кафе
# 15256  15256  221900             шоколадница    сетевые        кафе
# 15257  15257  222535             шоколадница    сетевые        кафе
#
#                                                                                              address  \
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h2>Комментарий ревьюера</h2>
#
# Да, ты верно заметил, что разное написание имеют улицы. Выше видно, что для Крутицкого переулка совпадения не нашлось, хотя он есть в таблице с районами (ниже). Тут нужно оценить количество полученных пропусков. Я могу предложить альтернативное решение, после которого может стать лучше: не менять местами слова в ячейках, а сделать `split`, удалить пробелы и сделать ячейки множествами (не знаю можно так или нет), тогда можно смержить по множествам. Если нельзя так мержить, то можно просто добавить стобцы руками циклом
# </div>

# %%
#Код ревьюера
all_street_list[all_street_list['street_name'].str.contains('Крутицкий')]
# Out:
#                 street_name     dist_name
# 79  Крутицкий 1-й, переулок     Таганский
# 80  Крутицкий 3-й, переулок     Таганский
# 81  Крутицкий 4-й, переулок     Таганский
# 11  Крутицкий 2-й, переулок  Южнопортовый
# 12  Крутицкий 3-й, переулок  Южнопортовый
# 13     Крутицкий Вал, улица  Южнопортовый

# %%
#Код ревьюера
#Идея такая

stop_words = [',']

addr_1 = "Крутицкий 3-й, переулок"

addr_2 = "3-й Крутицкий переулок"

addr_1 = addr_1.replace(',','')

addr_1 = set(elem.strip() for elem in addr_1.split())
addr_2 = set(elem.strip() for elem in addr_2.split())

display(addr_1)
display(addr_2)
display(addr_1 == addr_2)
# Out:
# {'3-й', 'Крутицкий', 'переулок'}
# {'3-й', 'Крутицкий', 'переулок'}
# True

# %% [markdown]
# ### Постройте график топ-10 улиц по количеству объектов общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос - в каких районах Москвы находятся эти улицы?

# %%
objects_street = all_data.pivot_table(index = 'format_street',aggfunc={'id':'count', 'number':'sum', 'dist_name':'first'}).sort_values(by='id', ascending=False).reset_index()
objects_street = objects_street.rename(columns={'id':'total_objects', 'number':'number_of_seats'})
top_street_10 = objects_street.head(11)

# Уберем город Зеленоград:
top_street_10 = top_street_10.loc[1:11]

plt.figure(figsize=(15,6))
g=sns.barplot(x='total_objects', y='format_street', data=top_street_10)
g.set_title("Топ 10 улиц по количеству объектов общественного питания", fontdict=({'fontsize':20}));
g.set_xlabel("Количество объектов")
g.set_ylabel("")

display("Районы расположения улиц: ", top_street_10)
# Out:
# 'Районы расположения улиц: '
#              format_street  \
# 1            Мира проспект
# 2        Профсоюзная улица
# 3   Ленинградский проспект
# 4   Пресненская набережная
# 5         Варшавское шоссе
# 6       Ленинский проспект
# 7     Вернадского проспект
# 8     Кутузовский проспект
# 9          Каширское шоссе
# 10    Кировоградская улица
#
#                                                                                                                              dist_name  \
# 1                                              [Алексеевский, Марьина роща, Мещанский, Останкинский, Ростокино, Свиблово, Ярославский]
# 2                                                              [Академический, Коньково, Обручевский, Тёплый Стан, Черёмушки, Ясенево]
# 3                                                                                              [Аэропорт, Беговой, Сокол, Хорошёвский]
# ...

# %% [markdown]
# <div class="alert alert-info"> Вывод: В топ 10 улиц по количеству объектов вошли: Кировоградская улица, Каширское шоссе, Кутузовский проспект, Вернадского проспект, Ленинский проспект, Варшавское шоссе, Пресненская набережная, Ленинградский проспект, Профсоюзная улица, Мира проспект, . Количество объектов на данных улицах составляет приблизительно от 100 до 200.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Зеленоград в принципе нас наверное мало интересует, поэтому можно его не учитывать. Тут можно заметить, что это не столько плотные улицы, сколько длинные. Есть идеи как найти плотные? Для этого надо придумать метрику, которая бы нормализовывала улицы по длине
#
# </div>

# %% [markdown]
# <div class="alert alert-info"><h2> Комментарий студента 2:</h2> Город Зеленоград убрал из списка топ 10 улиц. Метрикой вероятно можно взять - количество объектов на один район улицы. Тогда список улиц и график будут следующими:

# %% [markdown]
# <div class='alert alert-success'>
# <h2>Комментарий ревьюера V.2</h2>
#
# Да, хорошая идея :)
# </div>

# %%
street_density = pd.DataFrame()

street_density = all_data.copy()

#Найдем количество районов, которые пересекает улица:
street_density['number_of_district'] = street_density['dist_name'].str.len()

pivot = street_density.groupby('format_street').agg({'id':'count','number_of_district':'first', 'dist_name':'first'}).sort_values(by='id', ascending=False).reset_index()

# Посчитаем плотность объектов улицы по районам:
pivot['objects_per_district'] = round(pivot['id'] / pivot['number_of_district'],1)

pivot = pivot.sort_values(by='objects_per_district', ascending=False)
display(pivot.head(10))

plt.figure(figsize=(15,6))
g=sns.barplot(x='objects_per_district', y='format_street', data=pivot.head(10))
g.set_title("Топ 10 улиц по количеству объектов общественного питания", fontdict=({'fontsize':20}));
g.set_xlabel("Количество объектов")
g.set_ylabel("")
# Out:
#               format_street   id  number_of_district      dist_name  \
# 4    Пресненская набережная  167                 1.0    Пресненский
# 11        Ходынский бульвар  102                 1.0    Хорошёвский
# 14        Новый Арбат улица   92                 1.0          Арбат
# 15  Ленинская Слобода улица   89                 1.0    Даниловский
# 17          Пятницкая улица   80                 1.0  Замоскворечье
# 23              Арбат улица   77                 1.0          Арбат
# 22           Покровка улица   77                 1.0      Басманный
# 27           Тверская улица   68                 1.0       Тверской
# 28      Автозаводская улица   67                 1.0    Даниловский
# 29        Ярославское шоссе   65                 1.0    Ярославский
#
#     objects_per_district
# 4                  167.0
# 11                 102.0
# 14                  92.0
# 15                  89.0
# 17                  80.0
# 23                  77.0
# 22                  77.0
# ...

# %% [markdown]
# ### Найдите число улиц с одним объектом общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос — в каких районах Москвы находятся эти улицы?

# %%
one_object_street = objects_street.query('total_objects == 1')
display("Число улиц с одним объектом  общестаенного питания: " + str(one_object_street['format_street'].count()))
display("Районы в которых расположены улицы: ", one_object_street.sort_values(by='number_of_seats', ascending=False))
# Out:
# 'Число улиц с одним объектом  общестаенного питания: 569'
# 'Районы в которых расположены улицы: '
#                                        format_street  \
# 1776                              Ростокинская улица
# 1769                                Родниковая улица
# 1368                              7-я Северная линия
# 1919                                 Печорская улица
# 1408                                 Янтарный проезд
# 1539                             1-я Напрудная улица
# 1519                                 Фруктовая улица
# 1682                                   Кошкина улица
# 1768                                   Ротерта улица
# 1767                                Норильская улица
# 1892                                  Остафьево село
# 1561                                Чукотский проезд
# 1851                                 Брусилова улица
# 1915                                   Вербная улица
# 1502                           2-й Сетуньский проезд
# ...

# %% [markdown]
# <div class="alert alert-info"> Вывод: Число улиц с одним объектом  общестаенного питания составляет 569.

# %% [markdown]
# ### Посмотрите на распределение количества посадочных мест для улиц с большим количеством объектов общественного питания. Какие закономерности можно выявить?

# %%
display(objects_street.head(2))
plt.figure(figsize=(16,5))
g=sns.jointplot(x='total_objects', y='number_of_seats', color='brown', data=objects_street.head(50), height=10, kind='reg')
plt.title('Распределение числа посадочных мест, на улицах с большим количеством объектов', fontdict=({'fontsize':18}), loc='left')
g.set_axis_labels("Количество объектов расположенных на улице", "Посадочные места")
plt.show()
# Out:
#       format_street  \
# 0  город Зеленоград
# 1     Мира проспект
#
#                                                                                  dist_name  \
# 0                                                                                      NaN
# 1  [Алексеевский, Марьина роща, Мещанский, Останкинский, Ростокино, Свиблово, Ярославский]
#
#    total_objects  number_of_seats
# 0            232            17050
# 1            203            12790

# %% [markdown]
# <div class="alert alert-info"> Вывод: Возьмем топ 50 улиц по количеству объектов, на графике распределения обнаруживается, что на данных улицах расположенны объекты числом от 50 до 100 с общим числом посадочных мест до 5000.

# %% [markdown]
# <div class='alert alert-success'>
# <h2>Комментарий ревьюера</h2>
#
# Тут уже видно ненужную очевидную корреляцию, тут лучше было либо гистограмму построить, либо взятб топ10 улиц и для них построить по боксплоту числа мест для каждой
# </div>

# %% [markdown]
# <div class="alert alert-info"><h2> Комментарий студента 2:</h2> Построил график распредления числа посадочных мест для топ 10 улиц.

# %%
top_street_10_list = top_street_10['format_street']
display(top_street_10_list)
# Out:
# 1              Мира проспект
# 2          Профсоюзная улица
# 3     Ленинградский проспект
# 4     Пресненская набережная
# 5           Варшавское шоссе
# 6         Ленинский проспект
# 7       Вернадского проспект
# 8       Кутузовский проспект
# 9            Каширское шоссе
# 10      Кировоградская улица
# Name: format_street, dtype: object

# %%
allocation = all_data.loc[all_data['format_street'].isin(top_street_10_list)]
display(allocation.head(1))

plt.figure(figsize=(16,8))
g=sns.boxplot(data=allocation, x='number', y='format_street')
g.set(xlabel='Количество посадочных мест')
g.set(xlim=(0, 500))
plt.title('Распределение количества посадочных мест для улиц с большим количеством объектов', fontdict=({'fontsize':25}))
# Out:
#      index      id      object_name    chain object_type  \
# 151    151  155973  кафе «андерсон»  сетевые        кафе
#
#                                    address  number  \
# 151  город Москва, Варшавское шоссе, дом 2     150
#
#                                   split_street            street  \
# 151  [город Москва,  Варшавское шоссе,  дом 2]  Варшавское шоссе
#
#         format_street       street_name  \
# 151  Варшавское шоссе  Варшавское шоссе
#
#                                                                                                                               dist_name
# 151  [Бутово Северное, Бутово Южное, Донской, Нагатино-Садовники, Нагорный, Чертаново Северное, Чертаново Центральное, Чертаново Южное]
# Text(0.5, 1.0, 'Распределение количества посадочных мест для улиц с большим количеством объектов')

# %% [markdown]
# <div class="alert alert-info"> Общий вывод: Большее число объектов принадлежит к типу кафе, столовым, ресторанам и предприятиям быстрого обслуживания. Сетевых объектов в 4 раза меньше несетевых: 2968 против 12398. 3 типа объектов общественного питания имеют относительно значимую долю сетевых объектов - это кафе, рестораны и предприятия быстрого обслуживания. Для сетевых заведений характерно - не большое количество заведений - до 10, среднее значение количества посадочных мест до 100. Самое высокое среднее значение посадочных мест в столовых, достигает 100. Далее следуют рестораны - около 80, кафе, бары и буфеты со значением - около 30. Закусочные, предприятия быстрого обслуживания, кафетерии, отделы кулинарии в магазинах имеют единицы посадочных мест или 0. Топ 10 улиц по количеству объектов - Каширское шоссе, Кутузовский проспект, Вернадского проспект, Ленинский проспект, Варшавское шоссе, Пресненская набережная, Ленинградский проспект, Профсоюзная улица, Мира проспект, город Зеленоград. Количество объектов на данных улицах составляет от 100 до 200. Число улиц с одним объектом общестаенного питания - 569. Возьмем топ 50 улиц по количеству объектов, на графике распределения обнаруживается, что на данных улицах расположенны объекты числом от 50 до 100 с общим числом посадочных мест до 5000.

# %% [markdown]
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера</h2>
#
# Всё здорво, а как же "дайте рекомендации о виде заведения, количестве посадочных мест, а также районе расположения. Прокомментируйте возможность развития сети."?
# </div>

# %% [markdown]
# <div class="alert alert-info"><h2> Комментарий студента 2:</h2> Рекомендации по виду заведения - лучше открывать кафе. Потому что их больше всего, значит это популярный тип объектов. С количество мест - от 20 до 50, как видно из графика ниже таких кафе больше всего, значит это выгодно и наиболее распространнено. В районе пересекающимся улицей из топ 10. Возможность развития в сеть есть, т.к четверть всех кафе явлюятся сетевыми.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера V.2</h2>
#
# 👍
# </div>

# %%
cafe = data[data['object_type'] == 'кафе']
plt.figure(figsize=(15,6))
g=sns.violinplot(data=cafe, x='number')

display(cafe.groupby('chain')['chain'].count())
# Out:
# chain
# несетевые    4662
# сетевые      1395
# Name: chain, dtype: int64
